# %%
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_breast_cancer

from my_tools import my_LogRegression

# %%
X, y = load_breast_cancer(return_X_y=True)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = my_LogRegression()

model.fit(X_train,y_train)

# %%
y_pred_train = model.Predict(X_train)
y_pred_test = model.Predict(X_test)

print("Accuracy score in training = ", accuracy_score(y_train, y_pred_train) )
print("Accuracy score in testing = ", accuracy_score(y_test, y_pred_test) )
# Out:
# Accuracy score in training =  0.9824175824175824
# Accuracy score in testing =  0.956140350877193
